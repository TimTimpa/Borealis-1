# %% [markdown]
# **Detta är förarbetet som krävs för att koden ska fungera.**
#
# Den behöver bara köras en gång i början

# %%
import sys
# !git clone https://github.com/TimTimpa/Borealis-1.git
sys.path.insert(0, '/content/Borealis-1/data-analysis')
# %cd /content/Borealis-1/mission-data
from module_swe import *
# Out:
# Cloning into 'Borealis-1'...
# remote: Enumerating objects: 605, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 605 (delta 105), reused 162 (delta 85), pack-reused 411 (from 1)
# Receiving objects: 100% (605/605), 3.94 MiB | 14.87 MiB/s, done.
# Resolving deltas: 100% (308/308), done.
# /content/Borealis-1/mission-data
# /content/Borealis-1/data-analysis/module_swe.py:176: SyntaxWarning: invalid escape sequence '\s'
#   ax[j].plot(yrange, factor/(sigma * sqrt(2*pi)) * e**(- (yrange - mu)**2 / (2*sigma**2)), color=color, label=f'Normal Distribution:\n$\sigma = {sigma:.4f}$\n$\mu = {mu:.4f}$')
# /content/Borealis-1/data-analysis/module_swe.py:176: SyntaxWarning: invalid escape sequence '\m'
#   ax[j].plot(yrange, factor/(sigma * sqrt(2*pi)) * e**(- (yrange - mu)**2 / (2*sigma**2)), color=color, label=f'Normal Distribution:\n$\sigma = {sigma:.4f}$\n$\mu = {mu:.4f}$')

# %% [markdown]
# ---
# ---
#
# **Detta är eran kod**. Det är här som ni arbetar

# %%
data = läs('sample.csv')

graf = grafritare(data)
graf.rita()
graf.trend()
graf.visa()
